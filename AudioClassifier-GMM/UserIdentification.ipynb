# %% [markdown]
# # IMPORTS

# %%
from GMM import record_audio_train, train_model, record_audio_test, test_model
from sklearn import preprocessing
from sklearn.mixture import GaussianMixture
import pyaudio
import os
import wave
import numpy as np
import python_speech_features as mfccc
import pickle
import time
from scipy.io.wavfile import read

# %%
# ENTER THE USER NAME TO STORE THE DATA UNDER
Name = input("Enter your name: ")
# TOTAL NUMBER OF RECORDINGS
n_samples = 10

# %%
# RECORD THE DATA
record_audio_train(Name,n_samples)

# %%
# TRAIN THE MODEL
train_model(Name,n_samples)

# %%
# RECORD A NEW AUDIO TO BE ADDED IN TESTING SET
record_audio_test()

# %%
# TEST ALL AUDIO FILES IN testing_set and see results
test_model()
# Out:
# Enter your name: charlie
# --------record device list--------
# Input Device id 0 - HDA Intel PCH: ALC289 Analog (hw:0,0)
# Input Device id 20 - sysdefault
# Input Device id 26 - samplerate
# Input Device id 27 - speexrate
# Input Device id 28 - pulse
# Input Device id 29 - upmix
# Input Device id 30 - vdownmix
# Input Device id 32 - default
# --------------------------------------------------
# 32
# recording via index 32
# recording started
# recording stopped
# --------record device list--------
# Input Device id 28 - pulse
# Input Device id 32 - default
# --------------------------------------------------
# 32
# recording via index 32
# recording started
# recording stopped
# --------record device list--------
# Input Device id 28 - pulse
# Input Device id 32 - default
# --------------------------------------------------
# 32
# recording via index 32
# recording started
# recording stopped
# --------record device list--------
# Input Device id 28 - pulse
# ...
